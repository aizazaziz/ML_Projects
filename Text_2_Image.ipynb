# %% [markdown]
# <a href="https://colab.research.google.com/github/aizazaziz/ML_Projects/blob/main/Text_2_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import h5py
import pickle
import json

# !pip install rawpy
import rawpy

# !pip install OpenEXR
import OpenEXR

import Imath

import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras

Model = tf.keras.models.Model
Sequential = tf.keras.models.Sequential

import scipy
import matplotlib.pyplot as plt



import cv2
import skimage

import PIL
from PIL import Image
from PIL import Image, ImageEnhance, ImageFilter

import tqdm
import click
import flask
import logging

# Core ML Libraries
import transformers
import timm
import sentencepiece
import tokenizers

# Dataset streaming & large-scale data
import datasets

# Training utilities
import accelerate
# !pip install bitsandbytes
import bitsandbytes

# TensorFlow addons (extra layers)
# !pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.1 MB/s eta 0:00:00
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
# ...

# %%
from IPython.testing import test
train, test = tfds.load('imdb_reviews', split=('train', 'test'), as_supervised=True)

# %%
import pandas as pd

# %%
df = pd.read_csv("cars")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-913297007.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("cars")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...
